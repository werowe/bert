# %%
import random
import re
import numpy as np
import tensorflow as tf
from tensorflow import keras  
from tqdm import tqdm
from transformers import (
    AutoTokenizer,
    TFAutoModelForSequenceClassification,
)


# === CONFIGURATION CONSTANTS ===
LANGUAGE = 'en'
MODEL_TYPE = 'distilbert-base-uncased' if LANGUAGE == 'en' else 'distilbert-base-multilingual-cased'
MODEL_INPUTS = frozenset(['input_ids', 'attention_mask'])
 
EPOCHS = 2       # keep low for demo
 
NUM_DOCS = 10   # mock dataset size

BATCH_SIZE = 4
EVAL_BATCH_SIZE = 8
MAX_SEQ_LENGTH = 64

# === MOCK Avro-Like Data Generator ===
def mock_avro_reader(num_docs=NUM_DOCS):
    samples = [
        ("<p>This agreement is made between the company and the contractor.</p>", True),
        ("<h1>Invoice</h1><p>Date: 2024-09-12</p>", False),
        ("<div>Employment contract for the following individual...</div>", True),
        ("<p>Purchase order for materials...</p>", False),
        ("<div>Lease agreement details: terms, parties, rent.</div>", True),
        ("<p>Meeting notes: Project timeline, deliverables, next steps...</p>", False),
    ]
    for _ in range(num_docs):
        html, is_contract = random.choice(samples)
        yield {
            'body': html,
            'labels': {'contract': is_contract}
        }

# === MOCK html_labels2text ===
def html_labels2text(doc):
    # Very simple HTML-stripping mock
    text = re.sub('<[^<]+?>', '', doc['body'])
    return {'text': text}

# === PREPARE LABELLED DATA ===
labels_with_text = []
avro_reader = mock_avro_reader(NUM_DOCS)
for document in avro_reader:
    document_text = html_labels2text({'body': document['body']})['text']
    label = 1 if document['labels'].get('contract') else 0
    labels_with_text.append((label, document_text))

# === LOAD TOKENIZER ===
tokenizer = AutoTokenizer.from_pretrained(MODEL_TYPE)

def encode(text):
    inputs = tokenizer.encode_plus(
        text,
        add_special_tokens=True,
        padding='max_length',      # Explicitly pad to max length
        max_length=MAX_SEQ_LENGTH,
        truncation=True,
        return_tensors='tf',
    )
    return {k: v for k, v in inputs.items() if k in MODEL_INPUTS}

# === ENCODE DATA ===
data = [
    ({k: v[0] for k, v in encode(text).items()}, label)
    for label, text in tqdm(labels_with_text, desc="Encoding texts")
]

# === TF DATASET CREATION ===
def _data():
    yield from data

dataset = tf.data.Dataset.from_generator(
    _data,
    output_signature=(
        {k: tf.TensorSpec(shape=(MAX_SEQ_LENGTH,), dtype=tf.int32) for k in MODEL_INPUTS},
        tf.TensorSpec(shape=(), dtype=tf.int32),
    ),
)

dataset = dataset.shuffle(
    buffer_size=NUM_DOCS, seed=0, reshuffle_each_iteration=False
)

# === SPLIT TRAIN AND TEST ===
total_size = len(data)
train_size = int(0.9 * total_size)
test_size = total_size - train_size
train_dataset = dataset.take(train_size)
test_dataset = dataset.skip(train_size)
train_dataset = train_dataset.batch(BATCH_SIZE).repeat(-1)
test_dataset = test_dataset.batch(EVAL_BATCH_SIZE)

# === LOAD AND COMPILE MODEL ===
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL_TYPE, num_labels=2, from_pt=True)
optimizer = tf.keras.optimizers.Adam(learning_rate=3e-5)
loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metrics = ["accuracy"]
model.compile(optimizer=optimizer, loss=loss_fn, metrics=metrics)

steps_per_epoch = train_size // BATCH_SIZE
validation_steps = test_size // EVAL_BATCH_SIZE

# === TRAIN MODEL ===
model.fit(
    train_dataset,
    epochs=EPOCHS,
    steps_per_epoch=steps_per_epoch,
    validation_data=test_dataset,
    validation_steps=validation_steps
)

# === EVALUATE MODEL ===
results = model.evaluate(test_dataset, steps=validation_steps)
print(f"\nTest Loss: {results[0]:.4f} | Test Accuracy: {results[1]:.4f}")
# Out:
# Encoding texts: 100%|██████████| 10/10 [00:00<00:00, 2625.38it/s]
# 2025-10-06 10:34:43.811717: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 89.42MiB (rounded to 93763584)requested by op StatelessTruncatedNormalV2
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-10-06 10:34:43.811753: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1049] BFCAllocator dump for GPU_0_bfc
# 2025-10-06 10:34:43.811761: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (256): 	Total Chunks: 72, Chunks in use: 72. 18.0KiB allocated for chunks. 18.0KiB in use in bin. 413B client-requested in use in bin.
# 2025-10-06 10:34:43.811765: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811769: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2025-10-06 10:34:43.811773: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2048): 	Total Chunks: 224, Chunks in use: 224. 672.2KiB allocated for chunks. 672.2KiB in use in bin. 672.0KiB client-requested in use in bin.
# 2025-10-06 10:34:43.811776: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4096): 	Total Chunks: 8, Chunks in use: 8. 46.0KiB allocated for chunks. 46.0KiB in use in bin. 36.0KiB client-requested in use in bin.
# 2025-10-06 10:34:43.811780: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8192): 	Total Chunks: 23, Chunks in use: 23. 276.0KiB allocated for chunks. 276.0KiB in use in bin. 276.0KiB client-requested in use in bin.
# 2025-10-06 10:34:43.811784: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16384): 	Total Chunks: 1, Chunks in use: 1. 21.0KiB allocated for chunks. 21.0KiB in use in bin. 12.0KiB client-requested in use in bin.
# 2025-10-06 10:34:43.811787: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811790: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811793: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811795: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811798: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811802: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (1048576): 	Total Chunks: 2, Chunks in use: 1. 3.27MiB allocated for chunks. 1.50MiB in use in bin. 1.50MiB client-requested in use in bin.
# 2025-10-06 10:34:43.811806: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (2097152): 	Total Chunks: 103, Chunks in use: 103. 234.16MiB allocated for chunks. 234.16MiB in use in bin. 229.50MiB client-requested in use in bin.
# 2025-10-06 10:34:43.811810: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811814: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (8388608): 	Total Chunks: 47, Chunks in use: 47. 439.88MiB allocated for chunks. 439.88MiB in use in bin. 423.00MiB client-requested in use in bin.
# 2025-10-06 10:34:43.811817: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 16.84MiB allocated for chunks. 16.84MiB in use in bin. 9.00MiB client-requested in use in bin.
# 2025-10-06 10:34:43.811820: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811829: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (67108864): 	Total Chunks: 5, Chunks in use: 5. 480.85MiB allocated for chunks. 480.85MiB in use in bin. 447.10MiB client-requested in use in bin.
# 2025-10-06 10:34:43.811832: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811835: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1056] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-06 10:34:43.811839: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1072] Bin for 89.42MiB was 64.00MiB, Chunk State:
# 2025-10-06 10:34:43.811842: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1085] Next region of size 1233125376
# 2025-10-06 10:34:43.811847: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a000000 of size 1280 next 1
# 2025-10-06 10:34:43.811851: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a000500 of size 256 next 2
# 2025-10-06 10:34:43.811854: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a000600 of size 256 next 3
# 2025-10-06 10:34:43.811856: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a000700 of size 256 next 4
# 2025-10-06 10:34:43.811858: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a000800 of size 256 next 5
# 2025-10-06 10:34:43.811860: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1105] InUse at 7ae94a
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 10618112 totalling 10.13MiB
# 2025-10-06 10:34:43.812756: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 14155776 totalling 27.00MiB
# 2025-10-06 10:34:43.812758: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 16515072 totalling 15.75MiB
# 2025-10-06 10:34:43.812759: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 17657856 totalling 16.84MiB
# 2025-10-06 10:34:43.812761: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 2 Chunks of size 93763584 totalling 178.84MiB
# 2025-10-06 10:34:43.812763: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 97873920 totalling 93.34MiB
# 2025-10-06 10:34:43.812764: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 106168320 totalling 101.25MiB
# 2025-10-06 10:34:43.812766: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1113] 1 Chunks of size 112637952 totalling 107.42MiB
# 2025-10-06 10:34:43.812767: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1117] Sum Total of in-use chunks: 1.15GiB
# 2025-10-06 10:34:43.812770: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119] Total bytes in pool: 1233125376 memory_limit_: 1233125376 available bytes: 0 curr_region_allocation_bytes_: 2466250752
# 2025-10-06 10:34:43.812774: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1124] Stats:
# Limit:                      1233125376
# InUse:                      1231273984
# MaxInUse:                   1231274240
# NumAllocs:                        2006
# MaxAllocSize:                120858624
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-10-06 10:34:43.812780: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ***********************x****************************************************************************
# 2025-10-06 10:34:43.812795: W tensorflow/core/framework/op_kernel.cc:1855] OP_REQUIRES failed at stateless_random_ops_v2.cc:64 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[30522,768] and type float on /job:localhost/replica:0
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[7], line 103
#     100 test_dataset = test_dataset.batch(EVAL_BATCH_SIZE)
#     102 # === LOAD AND COMPILE MODEL ===
# --> 103 model = TFAutoModelForSequenceClassification.from_pretrained(MODEL_TYPE, num_labels=2, from_pt=True)
#     104 optimizer = tf.keras.optimizers.Adam(learning_rate=3e-5)
#     105 loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/models/auto/auto_factory.py:604, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     602     if model_class.config_class == config.sub_configs.get("text_config", None):
#     603         config = config.get_text_config()
# --> 604     return model_class.from_pretrained(
#     605         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     606     )
#     607 raise ValueError(
#     608     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     609     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping)}."
#     610 )
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/modeling_tf_utils.py:2941, in TFPreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2938     from .modeling_tf_pytorch_utils import load_pytorch_checkpoint_in_tf2_model
#    2940     # Load from a PyTorch checkpoint
# -> 2941     return load_pytorch_checkpoint_in_tf2_model(
#    2942         model,
#    2943         resolved_archive_file,
#    2944         allow_missing_keys=True,
#    2945         output_loading_info=output_loading_info,
#    2946         _prefix=load_weight_prefix,
#    2947         tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#    2948     )
#    2950 # we might need to extend the variable scope for composite models
#    2951 if load_weight_prefix is not None:
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/modeling_tf_pytorch_utils.py:212, in load_pytorch_checkpoint_in_tf2_model(tf_model, pytorch_checkpoint_path, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename)
#     208     pt_state_dict.update(state_dict)
#     210 logger.info(f"PyTorch checkpoint contains {sum(t.numel() for t in pt_state_dict.values()):,} parameters")
# --> 212 return load_pytorch_weights_in_tf2_model(
#     213     tf_model,
#     214     pt_state_dict,
#     215     tf_inputs=tf_inputs,
#     216     allow_missing_keys=allow_missing_keys,
#     217     output_loading_info=output_loading_info,
#     218     _prefix=_prefix,
#     219     tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#     220 )
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/modeling_tf_pytorch_utils.py:256, in load_pytorch_weights_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename)
#     252 # Numpy doesn't understand bfloat16, so upcast to a dtype that doesn't lose precision
#     253 pt_state_dict = {
#     254     k: v.numpy() if v.dtype != torch.bfloat16 else v.float().numpy() for k, v in pt_state_dict.items()
#     255 }
# --> 256 return load_pytorch_state_dict_in_tf2_model(
#     257     tf_model,
#     258     pt_state_dict,
#     259     tf_inputs=tf_inputs,
#     260     allow_missing_keys=allow_missing_keys,
#     261     output_loading_info=output_loading_info,
#     262     _prefix=_prefix,
#     263     tf_to_pt_weight_rename=tf_to_pt_weight_rename,
#     264 )
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/modeling_tf_pytorch_utils.py:330, in load_pytorch_state_dict_in_tf2_model(tf_model, pt_state_dict, tf_inputs, allow_missing_keys, output_loading_info, _prefix, tf_to_pt_weight_rename, ignore_mismatched_sizes, skip_logger_warnings)
#     328 if tf_inputs:
#     329     with tf.name_scope(_prefix):
# --> 330         tf_model(tf_inputs, training=False)  # Make sure model is built
#     331 # Convert old format to new format if needed from a PyTorch state_dict
#     332 tf_keys_to_pt_keys = {}
#
# File ~/tf_env/lib/python3.12/site-packages/tf_keras/src/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_tf_distilbert.py:843, in TFDistilBertForSequenceClassification.build(self, input_shape)
#     841 if getattr(self, "distilbert", None) is not None:
#     842     with tf.name_scope(self.distilbert.name):
# --> 843         self.distilbert.build(None)
#     844 if getattr(self, "pre_classifier", None) is not None:
#     845     with tf.name_scope(self.pre_classifier.name):
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_tf_distilbert.py:472, in TFDistilBertMainLayer.build(self, input_shape)
#     470 if getattr(self, "embeddings", None) is not None:
#     471     with tf.name_scope(self.embeddings.name):
# --> 472         self.embeddings.build(None)
#     473 if getattr(self, "transformer", None) is not None:
#     474     with tf.name_scope(self.transformer.name):
#
# File ~/tf_env/lib/python3.12/site-packages/transformers/models/distilbert/modeling_tf_distilbert.py:78, in TFEmbeddings.build(self, input_shape)
#      76 def build(self, input_shape=None):
#      77     with tf.name_scope("word_embeddings"):
# ---> 78         self.weight = self.add_weight(
#      79             name="weight",
#      80             shape=[self.config.vocab_size, self.dim],
#      81             initializer=get_initializer(initializer_range=self.initializer_range),
#      82         )
#      84     with tf.name_scope("position_embeddings"):
#      85         self.position_embeddings = self.add_weight(
#      86             name="embeddings",
#      87             shape=[self.max_position_embeddings, self.dim],
#      88             initializer=get_initializer(initializer_range=self.initializer_range),
#      89         )
#
# ResourceExhaustedError: {{function_node __wrapped__StatelessTruncatedNormalV2_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[30522,768] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:StatelessTruncatedNormalV2] name:
# /task:0/device:GPU:0 by allocator GPU_0_bfc
